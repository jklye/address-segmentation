# %% [markdown]
# # Data Variation (total 3 million)

# %% [markdown]
# ### Load clean address data with labelled components

# %%
import pandas as pd
import numpy as np
import re
import csv
import itertools

# %%
df_clean_w_labels = pd.read_pickle("./data/data_creation/cleaned_data_w_labels.pkl")
df_clean_w_labels
# Out:
#                                                   address block  \
# 0       BLOCK 170 ANG MO KIO AVENUE 4 KEBUN BARU LINK ...   170
# 1       170 ANG MO KIO AVENUE 4 KEBUN BARU LINK 1 #15-...   170
# 2       170 ANG MO KIO AVENUE 4 KEBUN BARU LINK 1 #27-...   170
# 3       170 ANG MO KIO AVENUE 4 KEBUN BARU LINK 1 #15-...   170
# 4       170 ANG MO KIO AVENUE 4 KEBUN BARU LINK 1 #25-...   170
# ...                                                   ...   ...
# 864478  863 WOODLANDS STREET 83 MY WORLD PRESCHOOL LTD...   863
# 864479  BLOCK 863 WOODLANDS STREET 83 MY WORLD PRESCHO...   863
# 864480  863 WOODLANDS STREET 83 MY WORLD PRESCHOOL LTD...   863
# 864481    864 WOODLANDS STREET 83 #07-57 SINGAPORE 730864   864
# 864482    879 WOODLANDS STREET 82 #10-87 SINGAPORE 730879   879
#
#                      street                 building floor_num unit_num  \
# 0       ANG MO KIO AVENUE 4        KEBUN BARU LINK 1        22       49
# 1       ANG MO KIO AVENUE 4        KEBUN BARU LINK 1        15       17
# 2       ANG MO KIO AVENUE 4        KEBUN BARU LINK 1        27       49
# 3       ANG MO KIO AVENUE 4        KEBUN BARU LINK 1        15       42
# 4       ANG MO KIO AVENUE 4        KEBUN BARU LINK 1        25       34
# ...                     ...                      ...       ...      ...
# 864478  WOODLANDS STREET 83  MY WORLD PRESCHOOL LTD.        20       80
# 864479  WOODLANDS STREET 83  MY WORLD PRESCHOOL LTD.        29       97
# 864480  WOODLANDS STREET 83  MY WORLD PRESCHOOL LTD.        17       07
# 864481  WOODLANDS STREET 83                      NaN        07       57
# 864482  WOODLANDS STREET 82                      NaN        10       87
#
#        postal_code    country
# 0           560170  SINGAPORE
# 1           560170  SINGAPORE
# 2           560170  SINGAPORE
# 3           560170  SINGAPORE
# 4           560170  SINGAPORE
# ...            ...        ...
# 864478      730863  SINGAPORE
# 864479      730863  SINGAPORE
# 864480      730863  SINGAPORE
# 864481      730864  SINGAPORE
# 864482      730879  SINGAPORE
#
# [864483 rows x 8 columns]

# %%
df2 = pd.read_pickle("./data/data_creation/cleaned_data_w_extended_fields.pkl")
# note: this dataframe contains more columns such as floor_unit and country_postal

# %%
data_to_be_varied = df2.sample(frac=1).reset_index(drop=True)
data_to_be_varied
# Out:
#                                                   address block  \
# 0       374 BUKIT BATOK STREET 31 #15-10 SINGAPORE 650374   374
# 1                115 PENDING ROAD #28-72 SINGAPORE 670115   115
# 2         230 PASIR RIS STREET 21 #24-19 SINGAPORE 510230   230
# 3       126 YISHUN STREET 11 CHONG PANG VIEW #28-39 SI...   126
# 4       988C JURONG WEST STREET 93 #26-70 SINGAPORE 64...  988C
# ...                                                   ...   ...
# 864478  179 BUKIT BATOK WEST AVENUE 8 #21-96 SINGAPORE...   179
# 864479       334 HOUGANG AVENUE 5 #19-41 SINGAPORE 530334   334
# 864480  BLOCK 323 SEMBAWANG CLOSE #01-04 SINGAPORE 750323   323
# 864481  418 ANG MO KIO AVENUE 10 TECK GHEE HEARTLANDS ...   418
# 864482  706 CLEMENTI WEST STREET 2 #25-42 SINGAPORE 12...   706
#
#                            street               street_name street_num  \
# 0           BUKIT BATOK STREET 31       BUKIT BATOK STREET          31
# 1                    PENDING ROAD              PENDING ROAD
# 2             PASIR RIS STREET 21         PASIR RIS STREET          21
# 3                YISHUN STREET 11            YISHUN STREET          11
# 4           JURONG WEST STREET 93       JURONG WEST STREET          93
# ...                           ...                       ...        ...
# 864478  BUKIT BATOK WEST AVENUE 8  BUKIT BATOK WEST AVENUE           8
# 864479           HOUGANG AVENUE 5           HOUGANG AVENUE           5
# 864480            SEMBAWANG CLOSE           SEMBAWANG CLOSE
# 864481       ANG MO KIO AVENUE 10        ANG MO KIO AVENUE          10
# 864482     CLEMENTI WEST STREET 2     CLEMENTI WEST STREET           2
#
#                     building floor_unit floor_num unit_num    country  \
# 0                                #15-10        15       10  SINGAPORE
# 1                                #28-72        28       72  SINGAPORE
# 2                                #24-19        24       19  SINGAPORE
# 3            CHONG PANG VIEW     #28-39        28       39  SINGAPORE
# 4                                #26-70        26       70  SINGAPORE
# ...                      ...        ...       ...      ...        ...
# 864478                           #21-96        21       96  SINGAPORE
# 864479                           #19-41        19       41  SINGAPORE
# 864480                           #01-04        01       04  SINGAPORE
# 864481  TECK GHEE HEARTLANDS     #12-50        12       50  SINGAPORE
# 864482                           #25-42        25       42  SINGAPORE
#
#        postal_code    country_postal
# 0           650374  SINGAPORE 650374
# 1           670115  SINGAPORE 670115
# 2           510230  SINGAPORE 510230
# 3           760126  SINGAPORE 760126
# 4           643988  SINGAPORE 643988
# ...            ...               ...
# 864478      650179  SINGAPORE 650179
# 864479      530334  SINGAPORE 530334
# 864480      750323  SINGAPORE 750323
# 864481      560418  SINGAPORE 560418
# 864482      120706  SINGAPORE 120706
#
# [864483 rows x 12 columns]

# %%
def permute_address(df, fields_to_permute):
    '''
    Arguments:
        df (DataFrame): source dataframe
        fields_to_permute (List): address components which will be permuted (eg. ['street', 'building'])
    Return:
        df_permuted (DataFrame): dataframe with permuted addresses
    '''
    
    df_permuted = pd.DataFrame(columns=df.columns)

    # generate all permutations of the fields to be permuted
    field_permutations = list(itertools.permutations(fields_to_permute))

    # generate multiple permutations of the address and append to the new DataFrame
    for permutation in field_permutations:
        df_copy = df.copy()

        for index, row in df_copy.iterrows():
            # create a dict for the permuted addresses
            permuted_address = {}
            for i, field in enumerate(permutation):
                value = row[field]
                if pd.isna(value) or value=='':
                    continue
                # add the field-value pair to the permuted address dictionary
                permuted_address[field] = value

            # print(permuted_address.values())
            permuted_mid = ' '.join(permuted_address.values())
            permuted_address_str = str(row['block']) + " " + permuted_mid + " " + str(row['country_postal'])

            # update the 'address' column with the permuted address
            df_copy.at[index, 'address'] = permuted_address_str
            
        df_permuted = pd.concat([df_permuted, df_copy]).drop_duplicates(subset=['address'], ignore_index=True).replace(r'^\s*$', np.nan, regex=True)
    df_permuted = df_permuted[['address', 'block', 'street', 'building', 'floor_num', 'unit_num', 'postal_code', 'country']]

    return df_permuted

# %% [markdown]
# ### Permute Kaggle data

# %%
fields = ['street', 'floor_unit', 'building']

df_permuted_w_labels = permute_address(data_to_be_varied, fields)
df_permuted_w_labels
# Out:
#                                                    address block  \
# 0        374 BUKIT BATOK STREET 31 #15-10 SINGAPORE 650374   374
# 1                 115 PENDING ROAD #28-72 SINGAPORE 670115   115
# 2          230 PASIR RIS STREET 21 #24-19 SINGAPORE 510230   230
# 3        126 YISHUN STREET 11 #28-39 CHONG PANG VIEW SI...   126
# 4        988C JURONG WEST STREET 93 #26-70 SINGAPORE 64...  988C
# ...                                                    ...   ...
# 3302432  60 MARINE DRIVE GARDENS #06-27 MARINE DRIVE SI...    60
# 3302433  428 GARDEN HILL #09-13 BEDOK NORTH ROAD SINGAP...   428
# 3302434  286 FICUS VALE #12-06 YISHUN AVENUE 6 SINGAPOR...   286
# 3302435  43 AYER RAJAH NEIGHBOURHOOD POLICE POST #19-17...    43
# 3302436  418 TECK GHEE HEARTLANDS #12-50 ANG MO KIO AVE...   418
#
#                         street                              building  \
# 0        BUKIT BATOK STREET 31                                   NaN
# 1                 PENDING ROAD                                   NaN
# 2          PASIR RIS STREET 21                                   NaN
# 3             YISHUN STREET 11                       CHONG PANG VIEW
# 4        JURONG WEST STREET 93                                   NaN
# ...                        ...                                   ...
# 3302432           MARINE DRIVE                  MARINE DRIVE GARDENS
# 3302433       BEDOK NORTH ROAD                           GARDEN HILL
# 3302434        YISHUN AVENUE 6                            FICUS VALE
# 3302435     TEBAN GARDENS ROAD  AYER RAJAH NEIGHBOURHOOD POLICE POST
# 3302436   ANG MO KIO AVENUE 10                  TECK GHEE HEARTLANDS
#
#         floor_num unit_num postal_code    country
# 0              15       10      650374  SINGAPORE
# 1              28       72      670115  SINGAPORE
# 2              24       19      510230  SINGAPORE
# 3              28       39      760126  SINGAPORE
# 4              26       70      643988  SINGAPORE
# ...           ...      ...         ...        ...
# 3302432        06       27      440060  SINGAPORE
# 3302433        09       13      460428  SINGAPORE
# 3302434        12       06      760286  SINGAPORE
# 3302435        19       17      600043  SINGAPORE
# 3302436        12       50      560418  SINGAPORE
#
# [3302437 rows x 8 columns]

# %%
df_permuted_w_labels.to_pickle("./data/data_variation/permuted_data_w_labels.pkl")
df_permuted_w_labels.to_csv(r'./data/data_variation/permuted_data_w_labels.csv', index=False)

# %% [markdown]
# ### Permute webscraped data

# %%
df_webscraped_w_labels = pd.read_csv("./data/webscraped_data/webscraped_data_w_labels.csv", dtype=str).dropna(subset=['address',]).drop_duplicates(subset=['address'], ignore_index=True).replace(r'^\s*$', np.nan, regex=True)
df_webscraped_w_labels
# Out:
#                                                 address block  \
# 0               21 THIRD CHIN BEE ROAD SINGAPORE 618694    21
# 1     6 UBI ROAD 1 #04-09 WINTECH CENTRE SINGAPORE 4...     6
# 2     52 UBI AVENUE 3 #04-39/40 FRONTIER SINGAPORE 4...    52
# 3     1 KAKI BUKIT ROAD 1 #03-17 ENTERPRISE ONE SING...     1
# 4                  8 TUAS VIEW CIRCUIT SINGAPORE 637777     8
# ...                                                 ...   ...
# 5896  3017 BEDOK NORTH STREET 5 #06-19 GOURMET EAST ...  3017
# 5897  BLOCK 15 WOODLANDS LOOP #01-01 WOODLANDS EAST ...    15
# 5898  15 WOODLANDS LOOP #03-00A WOODLANDS EAST INDUS...    15
# 5899  10 UBI CRESCENT #05-92 TO 95 UBI TECHPARK (LOB...    10
# 5900                 28 TUAS AVENUE 12 SINGAPORE 639043    28
#
#                     street                        building floor_num unit_num  \
# 0      THIRD CHIN BEE ROAD                             NaN       NaN      NaN
# 1               UBI ROAD 1                  WINTECH CENTRE         4        9
# 2             UBI AVENUE 3                        FRONTIER         4    39/40
# 3        KAKI BUKIT ROAD 1                  ENTERPRISE ONE         3       17
# 4        TUAS VIEW CIRCUIT                             NaN       NaN      NaN
# ...                    ...                             ...       ...      ...
# 5896  BEDOK NORTH STREET 5            GOURMET EAST KITCHEN         6       19
# 5897        WOODLANDS LOOP  WOODLANDS EAST INDUSTRIAL PARK         1        1
# 5898        WOODLANDS LOOP  WOODLANDS EAST INDUSTRIAL PARK         3      00A
# 5899          UBI CRESCENT    TO 95 UBI TECHPARK (LOBBY E)         5       92
# 5900        TUAS AVENUE 12                             NaN       NaN      NaN
#
#         country postal_code
# 0     SINGAPORE      618694
# 1     SINGAPORE      408726
# 2     SINGAPORE      408867
# 3     SINGAPORE      415934
# 4     SINGAPORE      637777
# ...         ...         ...
# 5896  SINGAPORE      486121
# 5897  SINGAPORE      738322
# 5898  SINGAPORE      738322
# 5899  SINGAPORE      408564
# 5900  SINGAPORE      639043
#
# [5901 rows x 8 columns]

# %%
floor_unit_list = []
country_postal_list = []

for index, row in df_webscraped_w_labels.iterrows():
    if pd.isna(row["floor_num"]) or row["floor_num"]=='' or pd.isna(row["unit_num"]) or row["unit_num"]=='':
        floor_unit = ''
    else:
        floor_unit = '#' + str(row['floor_num']) + '-' + str(row['unit_num'])
    
    if pd.isna(row["country"]) or row["country"]=='' or pd.isna(row["postal_code"]) or row["postal_code"]=='':
        country_postal = ''
    else:
        country_postal = str(row['country']) + ' ' + str(row['postal_code'])
        
    floor_unit_list.append(floor_unit)
    country_postal_list.append(country_postal)
    
df_webscraped_w_labels = df_webscraped_w_labels.assign(floor_unit = floor_unit_list, country_postal = country_postal_list)    
    
fields = ['street', 'floor_unit', 'building']

df_web_permuted = permute_address(df_webscraped_w_labels, fields)
df_web_permuted
# Out:
#                                                  address block  \
# 0                21 THIRD CHIN BEE ROAD SINGAPORE 618694    21
# 1      6 UBI ROAD 1 #4-9 WINTECH CENTRE SINGAPORE 408726     6
# 2      52 UBI AVENUE 3 #4-39/40 FRONTIER SINGAPORE 40...    52
# 3      1 KAKI BUKIT ROAD 1 #3-17 ENTERPRISE ONE SINGA...     1
# 4                   8 TUAS VIEW CIRCUIT SINGAPORE 637777     8
# ...                                                  ...   ...
# 20970  896 SIME DARBY CENTRE #4-05E DUNEARN ROAD SING...   896
# 20971  3017 GOURMET EAST KITCHEN #6-19 BEDOK NORTH ST...  3017
# 20972  15 WOODLANDS EAST INDUSTRIAL PARK #1-1 WOODLAN...    15
# 20973  15 WOODLANDS EAST INDUSTRIAL PARK #3-00A WOODL...    15
# 20974  10 TO 95 UBI TECHPARK (LOBBY E) #5-92 UBI CRES...    10
#
#                      street                        building floor_num  \
# 0       THIRD CHIN BEE ROAD                             NaN       NaN
# 1                UBI ROAD 1                  WINTECH CENTRE         4
# 2              UBI AVENUE 3                        FRONTIER         4
# 3         KAKI BUKIT ROAD 1                  ENTERPRISE ONE         3
# 4         TUAS VIEW CIRCUIT                             NaN       NaN
# ...                     ...                             ...       ...
# 20970          DUNEARN ROAD               SIME DARBY CENTRE         4
# 20971  BEDOK NORTH STREET 5            GOURMET EAST KITCHEN         6
# 20972        WOODLANDS LOOP  WOODLANDS EAST INDUSTRIAL PARK         1
# 20973        WOODLANDS LOOP  WOODLANDS EAST INDUSTRIAL PARK         3
# 20974          UBI CRESCENT    TO 95 UBI TECHPARK (LOBBY E)         5
#
#       unit_num postal_code    country
# 0          NaN      618694  SINGAPORE
# 1            9      408726  SINGAPORE
# 2        39/40      408867  SINGAPORE
# 3           17      415934  SINGAPORE
# 4          NaN      637777  SINGAPORE
# ...        ...         ...        ...
# 20970      05E      589472  SINGAPORE
# 20971       19      486121  SINGAPORE
# 20972        1      738322  SINGAPORE
# 20973      00A      738322  SINGAPORE
# 20974       92      408564  SINGAPORE
#
# [20975 rows x 8 columns]

# %% [markdown]
# ### Combine clean data and permuted data

# %%
df_combined = pd.concat([df_clean_w_labels, df_permuted_w_labels, df_webscraped_w_labels, df_web_permuted]).drop_duplicates(subset=['address'], ignore_index=True)[['address', 'block', 'street', 'building', 'floor_num', 'unit_num', 'postal_code', 'country']]
df_combined
# Out:
#                                                    address block  \
# 0        BLOCK 170 ANG MO KIO AVENUE 4 KEBUN BARU LINK ...   170
# 1        170 ANG MO KIO AVENUE 4 KEBUN BARU LINK 1 #15-...   170
# 2        170 ANG MO KIO AVENUE 4 KEBUN BARU LINK 1 #27-...   170
# 3        170 ANG MO KIO AVENUE 4 KEBUN BARU LINK 1 #15-...   170
# 4        170 ANG MO KIO AVENUE 4 KEBUN BARU LINK 1 #25-...   170
# ...                                                    ...   ...
# 3449103  896 SIME DARBY CENTRE #4-05E DUNEARN ROAD SING...   896
# 3449104  3017 GOURMET EAST KITCHEN #6-19 BEDOK NORTH ST...  3017
# 3449105  15 WOODLANDS EAST INDUSTRIAL PARK #1-1 WOODLAN...    15
# 3449106  15 WOODLANDS EAST INDUSTRIAL PARK #3-00A WOODL...    15
# 3449107  10 TO 95 UBI TECHPARK (LOBBY E) #5-92 UBI CRES...    10
#
#                        street                        building floor_num  \
# 0         ANG MO KIO AVENUE 4               KEBUN BARU LINK 1        22
# 1         ANG MO KIO AVENUE 4               KEBUN BARU LINK 1        15
# 2         ANG MO KIO AVENUE 4               KEBUN BARU LINK 1        27
# 3         ANG MO KIO AVENUE 4               KEBUN BARU LINK 1        15
# 4         ANG MO KIO AVENUE 4               KEBUN BARU LINK 1        25
# ...                       ...                             ...       ...
# 3449103          DUNEARN ROAD               SIME DARBY CENTRE         4
# 3449104  BEDOK NORTH STREET 5            GOURMET EAST KITCHEN         6
# 3449105        WOODLANDS LOOP  WOODLANDS EAST INDUSTRIAL PARK         1
# 3449106        WOODLANDS LOOP  WOODLANDS EAST INDUSTRIAL PARK         3
# 3449107          UBI CRESCENT    TO 95 UBI TECHPARK (LOBBY E)         5
#
#         unit_num postal_code    country
# 0             49      560170  SINGAPORE
# 1             17      560170  SINGAPORE
# 2             49      560170  SINGAPORE
# 3             42      560170  SINGAPORE
# 4             34      560170  SINGAPORE
# ...          ...         ...        ...
# 3449103      05E      589472  SINGAPORE
# 3449104       19      486121  SINGAPORE
# 3449105        1      738322  SINGAPORE
# 3449106      00A      738322  SINGAPORE
# 3449107       92      408564  SINGAPORE
#
# [3449108 rows x 8 columns]

# %%
df_combined.to_pickle("./data/data_variation/combined_data_w_labels.pkl")
df_combined.to_csv(r'./data/data_variation/combined_data_w_labels.csv', index=False)
